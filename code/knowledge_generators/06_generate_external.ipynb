# %% [markdown]
# # Generate External Context Store
#
# This notebook generates:
# - `events.json` - Time-bound events (COVID, regulatory)
# - `docs/*.md` - Domain knowledge documents
#
# Output: `knowledge_base/external/`

# %%
# TODO: Implement
